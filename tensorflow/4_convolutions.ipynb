# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-7-c56b394d9d7c>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.388811
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.235799
# Minibatch accuracy: 18.8%
# Validation accuracy: 17.3%
# Minibatch loss at step 100: 1.240095
# Minibatch accuracy: 56.2%
# Validation accuracy: 59.7%
# Minibatch loss at step 150: 0.702399
# Minibatch accuracy: 68.8%
# Validation accuracy: 72.5%
# Minibatch loss at step 200: 1.018078
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 250: 1.530945
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.5%
# Minibatch loss at step 300: 0.428219
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.3%
# Minibatch loss at step 350: 0.553744
# Minibatch accuracy: 93.8%
# Validation accuracy: 76.3%
# Minibatch loss at step 400: 0.405766
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 450: 0.739747
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 500: 0.773835
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 550: 0.865325
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 600: 0.299720
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.848560
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 700: 0.811040
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.053337
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 800: 0.626776
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 850: 0.958573
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 900: 0.688683
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 950: 0.627912
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 1000: 0.409638
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Test accuracy: 89.4%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 6
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-17-efba5f339c5a>:60 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 3.120743
# Minibatch accuracy: 6.2%
# Validation accuracy: 15.9%
# Minibatch loss at step 50: 2.197568
# Minibatch accuracy: 18.8%
# Validation accuracy: 22.4%
# Minibatch loss at step 100: 1.284268
# Minibatch accuracy: 56.2%
# Validation accuracy: 57.2%
# Minibatch loss at step 150: 0.896766
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.2%
# Minibatch loss at step 200: 1.073954
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.2%
# Minibatch loss at step 250: 1.219844
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 300: 0.370728
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 350: 0.524511
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 400: 0.191971
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 450: 1.217095
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 500: 0.902240
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 550: 0.804829
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 600: 0.365206
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 650: 0.883136
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 700: 0.982145
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 750: 0.029217
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 800: 0.610897
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 850: 0.891238
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 900: 0.669976
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 950: 0.459887
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 1000: 0.440420
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 32
patch_size_1 = 6
depth_1 = 6
patch_size_2 = 6
depth_2 = 16
patch_size_3 = 6
depth_3 = 64
num_hidden = 128
graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.get_variable('W1', shape=[patch_size_1 , patch_size_1, num_channels, depth_1], initializer=tf.contrib.layers.xavier_initializer()) 
    #tf.Variable(tf.truncated_normal([patch_size_1, patch_size_1, num_channels, depth_1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth_1]))
  layer2_weights = tf.get_variable('W2', shape=[patch_size_2 , patch_size_2, depth_1, depth_2], initializer=tf.contrib.layers.xavier_initializer()) 
    #tf.Variable(tf.truncated_normal([patch_size_2, patch_size_2, depth_1, depth_2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth_2]))
  layer3_weights = tf.get_variable('W3', shape=[patch_size_3 , patch_size_3, depth_2, depth_3], initializer=tf.contrib.layers.xavier_initializer()) 
    #tf.Variable(tf.truncated_normal([patch_size_3, patch_size_3, depth_2, depth_3], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth_3]))
  layer4_weights = tf.get_variable('W4', shape=[image_size // 4 * image_size // 4 * depth_3, num_hidden], initializer=tf.contrib.layers.xavier_initializer()) 
    #tf.Variable(tf.truncated_normal([image_size // 4 * image_size // 4 * depth_3, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.get_variable('W5', shape=[num_hidden , num_labels], initializer=tf.contrib.layers.xavier_initializer()) 
    #tf.Variable(tf.truncated_normal([num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  
  # Model.
  def model(data, train):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    if(train==1):
        hidden = tf.nn.dropout(hidden,0.5)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    if(train==1):
        hidden = tf.nn.dropout(hidden,0.5)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    conv = tf.nn.conv2d(pool, layer3_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer3_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset,1)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.02).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset,0))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset,0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset,0))

num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# WARNING:tensorflow:From <ipython-input-43-c6d0f196e67f>:73 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Minibatch loss at step 0: 6.181210
# Minibatch accuracy: 9.4%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.898113
# Minibatch accuracy: 28.1%
# Validation accuracy: 23.6%
# Minibatch loss at step 100: 1.169250
# Minibatch accuracy: 56.2%
# Validation accuracy: 65.7%
# Minibatch loss at step 150: 0.349680
# Minibatch accuracy: 90.6%
# Validation accuracy: 74.7%
# Minibatch loss at step 200: 0.562676
# Minibatch accuracy: 81.2%
# Validation accuracy: 72.6%
# Minibatch loss at step 250: 0.736574
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 300: 0.526049
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 350: 0.877060
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 400: 0.709222
# Minibatch accuracy: 78.1%
# Validation accuracy: 78.1%
# Minibatch loss at step 450: 0.874565
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 500: 0.396854
# Minibatch accuracy: 78.1%
# Validation accuracy: 76.9%
# Minibatch loss at step 550: 0.659334
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.4%
# Minibatch loss at step 600: 0.881627
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 650: 0.276527
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 700: 0.314780
# Minibatch accuracy: 84.4%
# Validation accuracy: 79.3%
# Minibatch loss at step 750: 0.502527
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 800: 0.910366
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 850: 0.602045
# Minibatch accuracy: 78.1%
# Validation accuracy: 79.6%
# Minibatch loss at step 900: 0.553354
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.4%
# Minibatch loss at step 950: 0.425985
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 1000: 0.374237
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.7%
# Minibatch loss at step 1050: 0.162497
# Minibatch accuracy: 96.9%
# Validation accuracy: 80.6%
# Minibatch loss at step 1100: 0.384423
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1150: 0.732659
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 1200: 0.422381
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 1250: 0.827268
# Minibatch accuracy: 71.9%
# Validation accuracy: 84.0%
# Minibatch loss at step 1300: 0.195111
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.6%
# Minibatch loss at step 1350: 0.321504
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.7%
# Minibatch loss at step 1400: 0.369413
# Minibatch accuracy: 90.6%
# Validation accuracy: 81.1%
# Minibatch loss at step 1450: 0.681585
# Minibatch accuracy: 78.1%
# Validation accuracy: 83.8%
# Minibatch loss at step 1500: 0.313055
# Minibatch accuracy: 90.6%
# Validation accuracy: 83.8%
# Minibatch loss at step 1550: 0.511304
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 1600: 0.279911
# Minibatch accuracy: 90.6%
# Validation accuracy: 84.9%
# Minibatch loss at step 1650: 0.216867
# Minibatch accuracy: 96.9%
# Validation accuracy: 81.3%
# Minibatch loss at step 1700: 0.750264
# Minibatch accuracy: 71.9%
# Validation accuracy: 84.8%
# Minibatch loss at step 1750: 0.663150
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 1800: 0.285469
# Minibatch accuracy: 90.6%
# Validation accuracy: 82.5%
# Minibatch loss at step 1850: 0.853161
# Minibatch accuracy: 71.9%
# Validation accuracy: 84.4%
# Minibatch loss at step 1900: 0.227357
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 1950: 0.590277
# Minibatch accuracy: 84.4%
# Validation accuracy: 84.9%
# Minibatch loss at step 2000: 0.249973
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 2050: 0.427543
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.4%
# Minibatch loss at step 2100: 0.350781
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 2150: 0.684359
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.4%
# Minibatch loss at step 2200: 1.011771
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 2250: 0.478368
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.6%
# Minibatch loss at step 2300: 0.526633
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.5%
# Minibatch loss at step 2350: 0.481850
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 2400: 0.384988
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 2450: 0.317815
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.3%
# Minibatch loss at step 2500: 0.583180
# Minibatch accuracy: 78.1%
# Validation accuracy: 85.1%
# Minibatch loss at step 2550: 0.501324
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 2600: 0.343244
# Minibatch accuracy: 84.4%
# Validation accuracy: 83.1%
# Minibatch loss at step 2650: 0.458545
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 2700: 0.458534
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.7%
# Minibatch loss at step 2750: 0.620268
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 2800: 0.562785
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 2850: 0.510445
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 2900: 0.286197
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.8%
# Minibatch loss at step 2950: 0.723841
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 3000: 0.251622
# Minibatch accuracy: 90.6%
# Validation accuracy: 85.4%
# Minibatch loss at step 3050: 0.540655
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3100: 0.679084
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 3150: 0.609214
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 3200: 0.079587
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.8%
# Minibatch loss at step 3250: 0.592476
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 3300: 0.128844
# Minibatch accuracy: 96.9%
# Validation accuracy: 85.8%
# Minibatch loss at step 3350: 0.240852
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 3400: 0.373969
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.3%
# Minibatch loss at step 3450: 0.425475
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.1%
# Minibatch loss at step 3500: 0.495756
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 3550: 0.496674
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 3600: 0.402237
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3650: 0.410943
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 3700: 0.095800
# Minibatch accuracy: 96.9%
# Validation accuracy: 87.6%
# Minibatch loss at step 3750: 0.292067
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 3800: 0.472599
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.2%
# Minibatch loss at step 3850: 0.264083
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 3900: 0.349082
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.3%
# Minibatch loss at step 3950: 0.326159
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 4000: 0.333338
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 4050: 0.474198
# Minibatch accuracy: 84.4%
# Validation accuracy: 86.8%
# Minibatch loss at step 4100: 0.454105
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 4150: 0.326916
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 4200: 0.238021
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 4250: 0.199536
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.0%
# Minibatch loss at step 4300: 0.301206
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 4350: 0.267171
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 4400: 0.445733
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.7%
# Minibatch loss at step 4450: 0.523882
# Minibatch accuracy: 78.1%
# Validation accuracy: 86.4%
# Minibatch loss at step 4500: 0.292912
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 4550: 0.178916
# Minibatch accuracy: 90.6%
# Validation accuracy: 86.6%
# Minibatch loss at step 4600: 0.389590
# Minibatch accuracy: 84.4%
# Validation accuracy: 87.1%
# Minibatch loss at step 4650: 0.667418
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 4700: 0.232972
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 4750: 0.224821
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 4800: 0.352288
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 4850: 0.350678
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 4900: 0.233693
# Minibatch accuracy: 90.6%
# Validation accuracy: 87.5%
# Minibatch loss at step 4950: 0.515266
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 5000: 0.187130
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Test accuracy: 93.5%
